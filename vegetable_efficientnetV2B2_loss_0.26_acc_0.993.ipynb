# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
import os
import shutil
import glob
import zipfile
import cv2
import random as rd
import matplotlib.pyplot as plt

# %%
import time
import datetime

# %%
from tensorflow.keras.utils import image_dataset_from_directory
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder

import tensorflow_datasets as tfds

# %%
Root_dir = "/content"
Zip_dir = "/content/drive/MyDrive/data/vegetables.zip"
Data_dir = "/content/dataset"

if os.path.exists(Data_dir):
  print("기존 directory 삭제")
  shutil.rmtree(Data_dir)

#  Data 다운로드
#  confirm=t 추가해 바이러스 검사 x
Data_Url = "https://drive.google.com/uc?export=download&id=16kGefMea0BArS3pFBbba8xpWEqXJ9twH&confirm=t"
tf.keras.utils.get_file(
    os.path.join(Root_dir,"vegetables.zip"),
    origin=Data_Url,
    extract=True,
    cache_subdir="",
    cache_dir=Root_dir)

os.rename("/content/Vegetable Images","/content/dataset")
# Out:
# Downloading data from https://drive.google.com/uc?export=download&id=16kGefMea0BArS3pFBbba8xpWEqXJ9twH&confirm=t
# 560031432/560031432 [==============================] - 11s 0us/step

# %%
#각 라벨의 랜덤 이미지 1개의 주소 리턴
def get_img(dir):
  img_list = []
  label_name = []
  for i,veg_name in enumerate(os.listdir(dir)):
    veg_dir = dir+"/"+veg_name
    vegetables = glob.glob(veg_dir+"/**")
    veg_len = len(vegetables)
    label_count[veg_name] = veg_len
    img_index = rd.randrange(veg_len)
    img_dir = vegetables[img_index]
    img_list.append(img_dir)
    label_name.append(veg_name)

  return label_name,img_list

#이미지 주소 plt로 출력
def show_img(label_name,img_list):
  images = []
  plt.figure(figsize=(18,12))
  for i in range(len(img_list)):
    img = cv2.imread(img_list[i])
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    plt.subplot(3,5,i+1)
    plt.title(label_name[i])
    plt.axis(False)
    plt.imshow(img)
    images.append(img)
  plt.show()
  return images

# %%
# 데이터 세트 dir
train_dir , test_dir, val_dir = Data_dir + "/train" , Data_dir + "/test" , Data_dir + "/validation"

label_count={}

# 각 label의 랜덤한 사진 출력
start_time = time.time()

labels,imgs = get_img(train_dir)
imgs = show_img(labels,imgs)

end_time = time.time()
print("Progress time : ",end_time-start_time)

# %%
print(label_count)
# Out:
# Progress time :  1.6282904148101807
# {'Radish': 1000, 'Tomato': 1000, 'Broccoli': 1000, 'Cabbage': 1000, 'Potato': 1000, 'Pumpkin': 1000, 'Cucumber': 1000, 'Brinjal': 1000, 'Bitter_Gourd': 1000, 'Capsicum': 1000, 'Bean': 1000, 'Papaya': 1000, 'Bottle_Gourd': 1000, 'Cauliflower': 1000, 'Carrot': 1000}

# %%
randomState = 384   # 랜덤 시드
batchSize = 64
img_height,img_width = 144,144
epochs = 15

# %%
# ImageDataGenerator Deprecated

train_data = image_dataset_from_directory(
    train_dir,
    label_mode="int",
    seed = randomState,
    image_size = (img_height,img_width),
    batch_size = batchSize
)
val_data = image_dataset_from_directory(
    val_dir,
    label_mode="int",
    seed = randomState,
    image_size = (img_height,img_width),
    batch_size = batchSize,
    validation_split = 0.5,
    subset = "validation"
)
test_data = image_dataset_from_directory(
    test_dir,
    label_mode="int",
    seed = randomState,
    image_size = (img_height,img_width),
    batch_size = batchSize,
)
# Out:
# Found 15000 files belonging to 15 classes.
# Found 3000 files belonging to 15 classes.
# Using 1500 files for validation.
# Found 3000 files belonging to 15 classes.

# %%
classes = train_data.class_names
print(classes,end="\n"*4)

print(train_data)
# Out:
# ['Bean', 'Bitter_Gourd', 'Bottle_Gourd', 'Brinjal', 'Broccoli', 'Cabbage', 'Capsicum', 'Carrot', 'Cauliflower', 'Cucumber', 'Papaya', 'Potato', 'Pumpkin', 'Radish', 'Tomato']
#
#
#
# <BatchDataset element_spec=(TensorSpec(shape=(None, 144, 144, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
AUTOTUNE = tf.data.AUTOTUNE
# cache = 데이터셋을 메모리에 캐시하여 파일 열기 데이터 읽기 등을 첫 epoch 이후 재사용
# prefetch 데이터 미리 메모리에 load
# AUTOTUNE tf data 런타임이 값을 동적으로 조정
train_data = train_data.cache().prefetch(buffer_size=AUTOTUNE)
val_data = val_data.cache().prefetch(buffer_size=AUTOTUNE)
test_data = test_data.cache().prefetch(buffer_size=AUTOTUNE)

# %%
print(train_data)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 144, 144, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2B2
from tensorflow.keras import Sequential
from tensorflow.keras.layers import BatchNormalization, Dropout, Dense
from tensorflow.keras.layers import Rescaling

# %%
Pre_trained_model = EfficientNetV2B2(
    include_top = False,
    input_shape = (img_height,img_width,3),
    weights = "imagenet",
    pooling = "max"
)
# Pre_trained_model.trainable=False

# Pre_trained_model = Sequential([])
# Pre_trained_model.summary()

model = Sequential([
    Rescaling(1./255,input_shape=(img_height,img_width,3)),
    Pre_trained_model,
    BatchNormalization(),
    Dense(64,activation = "relu"),
    Dense(len(classes),activation = "softmax")
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b2_notop.h5
# 35839040/35839040 [==============================] - 2s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 144, 144, 3)       0
#
#  efficientnetv2-b2 (Function  (None, 1408)             8769374
#  al)
#
#  batch_normalization (BatchN  (None, 1408)             5632
#  ormalization)
#
#  dense (Dense)               (None, 64)                90176
#
#  dense_1 (Dense)             (None, 15)                975
#
# =================================================================
# Total params: 8,866,157
# Trainable params: 8,781,053
# Non-trainable params: 85,104
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=2e-5),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard, LearningRateScheduler

# %%
# tensorboard 로그
def log_dir():
  return os.path.join(Root_dir,"logs/") + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# LRScheduler용 함수
def scheduler(epoch,lr):
  if epoch <= 5:
    return lr
  else:
    return lr * 0.9

# %%
MCP_path=os.path.join(Root_dir,"checkpoint")

# %%
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=3)
'''
reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    patience=5,
    factor=0.1)
'''
model_checkpoint = ModelCheckpoint(
    MCP_path,
    verbose=1,
    mode="min",
    save_weights_only=True,
    save_best_only=True,
    monitor="val_loss")

tensor_board = TensorBoard(
    log_dir(),
    histogram_freq=1
)

LRScheduler = LearningRateScheduler(
    scheduler
)

# %%
history = model.fit(train_data,batch_size=32,epochs=epochs,validation_data=val_data,callbacks=[early_stop,model_checkpoint,tensor_board,LRScheduler])
# Out:
# Epoch 1/15
# 235/235 [==============================] - ETA: 0s - loss: 2.3122 - accuracy: 0.2987
# Epoch 1: val_loss improved from inf to 1.30856, saving model to /content/checkpoint
# 235/235 [==============================] - 137s 300ms/step - loss: 2.3122 - accuracy: 0.2987 - val_loss: 1.3086 - val_accuracy: 0.6227 - lr: 2.0000e-05
# Epoch 2/15
# 235/235 [==============================] - ETA: 0s - loss: 1.0295 - accuracy: 0.7189
# Epoch 2: val_loss improved from 1.30856 to 0.68230, saving model to /content/checkpoint
# 235/235 [==============================] - 65s 276ms/step - loss: 1.0295 - accuracy: 0.7189 - val_loss: 0.6823 - val_accuracy: 0.8253 - lr: 2.0000e-05
# Epoch 3/15
# 235/235 [==============================] - ETA: 0s - loss: 0.5318 - accuracy: 0.8669
# Epoch 3: val_loss improved from 0.68230 to 0.29549, saving model to /content/checkpoint
# 235/235 [==============================] - 64s 273ms/step - loss: 0.5318 - accuracy: 0.8669 - val_loss: 0.2955 - val_accuracy: 0.9300 - lr: 2.0000e-05
# Epoch 4/15
# 235/235 [==============================] - ETA: 0s - loss: 0.3147 - accuracy: 0.9233
# Epoch 4: val_loss improved from 0.29549 to 0.27440, saving model to /content/checkpoint
# 235/235 [==============================] - 64s 271ms/step - loss: 0.3147 - accuracy: 0.9233 - val_loss: 0.2744 - val_accuracy: 0.9260 - lr: 2.0000e-05
# Epoch 5/15
# 235/235 [==============================] - ETA: 0s - loss: 0.2069 - accuracy: 0.9521
# Epoch 5: val_loss improved from 0.27440 to 0.11819, saving model to /content/checkpoint
# 235/235 [==============================] - 64s 271ms/step - loss: 0.2069 - accuracy: 0.9521 - val_loss: 0.1182 - val_accuracy: 0.9687 - lr: 2.0000e-05
# Epoch 6/15
# 235/235 [==============================] - ETA: 0s - loss: 0.1472 - accuracy: 0.9668
# Epoch 6: val_loss improved from 0.11819 to 0.11793, saving model to /content/checkpoint
# 235/235 [==============================] - 65s 275ms/step - loss: 0.1472 - accuracy: 0.9668 - val_loss: 0.1179 - val_accuracy: 0.9673 - lr: 2.0000e-05
# Epoch 7/15
# 235/235 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9771
# Epoch 7: val_loss improved from 0.11793 to 0.06587, saving model to /content/checkpoint
# 235/235 [==============================] - 66s 280ms/step - loss: 0.1046 - accuracy: 0.9771 - val_loss: 0.0659 - val_accuracy: 0.9840 - lr: 1.8000e-05
# Epoch 8/15
# 235/235 [==============================] - ETA: 0s - loss: 0.0830 - accuracy: 0.9819
# Epoch 8: val_loss improved from 0.06587 to 0.05109, saving model to /content/checkpoint
# 235/235 [==============================] - 64s 273ms/step - loss: 0.0830 - accuracy: 0.9819 - val_loss: 0.0511 - val_accuracy: 0.9880 - lr: 1.6200e-05
# Epoch 9/15
# 235/235 [==============================] - ETA: 0s - loss: 0.0647 - accuracy: 0.9867
# Epoch 9: val_loss improved from 0.05109 to 0.04648, saving model to /content/checkpoint
# 235/235 [==============================] - 64s 271ms/step - loss: 0.0647 - accuracy: 0.9867 - val_loss: 0.0465 - val_accuracy: 0.9873 - lr: 1.4580e-05
# Epoch 10/15
# 235/235 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9900
# Epoch 10: val_loss improved from 0.04648 to 0.04267, saving model to /content/checkpoint
# 235/235 [==============================] - 64s 274ms/step - loss: 0.0541 - accuracy: 0.9900 - val_loss: 0.0427 - val_accuracy: 0.9887 - lr: 1.3122e-05
# Epoch 11/15
# 235/235 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 0.9919
# Epoch 11: val_loss improved from 0.04267 to 0.03836, saving model to /content/checkpoint
# 235/235 [==============================] - 65s 276ms/step - loss: 0.0468 - accuracy: 0.9919 - val_loss: 0.0384 - val_accuracy: 0.9907 - lr: 1.1810e-05
# Epoch 12/15
# 235/235 [==============================] - ETA: 0s - loss: 0.0394 - accuracy: 0.9925
# Epoch 12: val_loss improved from 0.03836 to 0.03694, saving model to /content/checkpoint
# 235/235 [==============================] - 64s 271ms/step - loss: 0.0394 - accuracy: 0.9925 - val_loss: 0.0369 - val_accuracy: 0.9920 - lr: 1.0629e-05
# Epoch 13/15
# 235/235 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9925
# Epoch 13: val_loss improved from 0.03694 to 0.03230, saving model to /content/checkpoint
# 235/235 [==============================] - 65s 278ms/step - loss: 0.0343 - accuracy: 0.9925 - val_loss: 0.0323 - val_accuracy: 0.9907 - lr: 9.5659e-06
# Epoch 14/15
# 235/235 [==============================] - ETA: 0s - loss: 0.0307 - accuracy: 0.9939
# Epoch 14: val_loss improved from 0.03230 to 0.02991, saving model to /content/checkpoint
# 235/235 [==============================] - 64s 274ms/step - loss: 0.0307 - accuracy: 0.9939 - val_loss: 0.0299 - val_accuracy: 0.9913 - lr: 8.6093e-06
# Epoch 15/15
# 235/235 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9957
# Epoch 15: val_loss did not improve from 0.02991
# 235/235 [==============================] - 63s 267ms/step - loss: 0.0266 - accuracy: 0.9957 - val_loss: 0.0310 - val_accuracy: 0.9927 - lr: 7.7484e-06

# %%
'''
# %load_ext tensorboard

# %tensorboard --logdir /content/logs
'''
# Out:
# '\n%load_ext tensorboard\n\n%tensorboard --logdir /content/logs\n'

# %%
def predicts(imgs):
  images = []
  for img in imgs:
    img = cv2.resize(img,dsize=(img_height,img_width))
    images.append(img)
  return np.argmax(model.predict(np.array(images)),axis=1)


def plot_confusion_matrix(trues,preds):
  cf = confusion_matrix(trues,preds)

  plt.figure(figsize=(10,10))
  plt.imshow(cf)
  plt.title("Confusion Matrix")
  plt.colorbar()
  class_len = np.arange(len(classes))
  plt.xticks(class_len,classes,rotation=25)
  plt.yticks(class_len,classes)

# %%
LE = LabelEncoder()
LE.fit(classes)
print(LE.classes_)
# Out:
# ['Bean' 'Bitter_Gourd' 'Bottle_Gourd' 'Brinjal' 'Broccoli' 'Cabbage'
#  'Capsicum' 'Carrot' 'Cauliflower' 'Cucumber' 'Papaya' 'Potato' 'Pumpkin'
#  'Radish' 'Tomato']

# %%
preds = predicts(imgs)
trues = LE.transform(labels)


plot_confusion_matrix(trues,preds)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
hist = history.history

metrics = list(hist.keys())
linestyles = ["-","-."]

# %%
plt.figure(figsize = (10,6))
for i in range(0,4,2):
  idx = i//2
  plt.plot(hist[metrics[i]],c="blue",label=metrics[i],alpha=0.8,linestyle=linestyles[idx])
  plt.plot(hist[metrics[i+1]],c="red",label=metrics[i+1],alpha=0.8,linestyle=linestyles[idx])
plt.xlabel("Epochs")
plt.legend();
plt.show()

# %%
model.load_weights(MCP_path)

# %%
result = model.evaluate(test_data)
print(result)
# Out:
# 47/47 [==============================] - 6s 117ms/step - loss: 0.0288 - accuracy: 0.9927
# [0.02883293107151985, 0.9926666617393494]
